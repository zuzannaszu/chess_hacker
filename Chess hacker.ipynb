# %%
import os
import cv2 as cv2
import random
import imageio
import numpy as np

from pathlib import Path
from glob import glob
import matplotlib.pyplot as plt

# %%
import cv2 as cv
img = cv2.imread("/Users/zuzannaszubartowska/code/zuzannaszu/chess_hacker/data/0.jpg")
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
plt.imshow(gray, cmap='gray')

# %%
blur = cv2.GaussianBlur(img, (5, 5), 0)
_, img_binary = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[39], line 2
#       1 blur = cv2.GaussianBlur(img, (5, 5), 0)
# ----> 2 _, img_binary = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
#
# error: OpenCV(4.7.0) /Users/xperience/GHA-OCV-Python/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/thresh.cpp:1555: error: (-2:Unspecified error) in function 'double cv::threshold(cv::InputArray, cv::OutputArray, double, double, int)'
# > THRESH_OTSU mode:
# >     'src_type == CV_8UC1 || src_type == CV_16UC1'
# > where
# >     'src_type' is 16 (CV_8UC3)
